# %%
# !sudo apt update -y
# !sudo apt install -y libcairo2-dev \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !pip install manim
# !pip install IPython==8.21.0

#!pip install -r requirements.txt

# !pip install ffmpeg-python

# %%
# !python pipeline.py
# Out:
# 2025-08-11 19:31:46.253625: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cpu
# NOTE: If you have a GPU, consider using it for training.
# On a Windows machine with NVidia GPU, check this video: https://www.youtube.com/watch?v=GMSjDTU8Zlc
# On a Mac machine, run: pip3 install --pre torch torchvision torchaudio torchtext --index-url https://download.pytorch.org/whl/nightly/cpu
# Reusing dataset opus_books (/home/sagemaker-user/.cache/huggingface/datasets/opus_books/en-pt/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf)
# [00:00:00] Pre-processing sequences       ██████████████████ 0        /        0No model to preload, starting from scratch██████████████████ 0        /        0
# Processing Epoch 00: 100%|████████████| 1/1 [00:00<00:00, 90.80it/s, loss=7.785]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 01: 100%|███████████| 1/1 [00:00<00:00, 101.47it/s, loss=7.758]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 02: 100%|███████████| 1/1 [00:00<00:00, 103.65it/s, loss=7.795]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 03: 100%|███████████| 1/1 [00:00<00:00, 104.63it/s, loss=7.784]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 04: 100%|███████████| 1/1 [00:00<00:00, 104.59it/s, loss=7.695]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 05: 100%|███████████| 1/1 [00:00<00:00, 104.63it/s, loss=7.793]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 06: 100%|███████████| 1/1 [00:00<00:00, 130.57it/s, loss=7.752]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 07: 100%|███████████| 1/1 [00:00<00:00, 104.15it/s, loss=7.738]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 08: 100%|███████████| 1/1 [00:00<00:00, 120.49it/s, loss=7.770]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 09: 100%|███████████| 1/1 [00:00<00:00, 126.03it/s, loss=7.753]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 10: 100%|███████████| 1/1 [00:00<00:00, 131.22it/s, loss=7.789]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 11: 100%|███████████| 1/1 [00:00<00:00, 103.82it/s, loss=7.733]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 12: 100%|███████████| 1/1 [00:00<00:00, 129.34it/s, loss=7.750]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 13: 100%|███████████| 1/1 [00:00<00:00, 125.50it/s, loss=7.722]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 14: 100%|███████████| 1/1 [00:00<00:00, 105.17it/s, loss=7.755]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 15: 100%|███████████| 1/1 [00:00<00:00, 104.87it/s, loss=7.727]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 16: 100%|███████████| 1/1 [00:00<00:00, 127.07it/s, loss=7.787]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 17: 100%|███████████| 1/1 [00:00<00:00, 105.68it/s, loss=7.763]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito desaparecer
# Processing Epoch 18: 100%|███████████| 1/1 [00:00<00:00, 106.05it/s, loss=7.751]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 19: 100%|███████████| 1/1 [00:00<00:00, 105.55it/s, loss=7.693]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 20: 100%|███████████| 1/1 [00:00<00:00, 105.54it/s, loss=7.781]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 21: 100%|███████████| 1/1 [00:00<00:00, 104.07it/s, loss=7.756]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 22: 100%|███████████| 1/1 [00:00<00:00, 105.77it/s, loss=7.717]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 23: 100%|███████████| 1/1 [00:00<00:00, 106.04it/s, loss=7.757]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch

# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 95: 100%|███████████| 1/1 [00:00<00:00, 122.62it/s, loss=7.704]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 96: 100%|███████████| 1/1 [00:00<00:00, 104.78it/s, loss=7.702]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 97: 100%|███████████| 1/1 [00:00<00:00, 105.53it/s, loss=7.687]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 98: 100%|███████████| 1/1 [00:00<00:00, 105.64it/s, loss=7.702]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
# Processing Epoch 99:   0%|                                | 0/1 [00:00<?, ?it/s]Ativado save_debug para: encoder.layers.0.self_attention_block
# Ativado save_debug para: encoder.layers.0.feed_forward_block
# Ativado save_debug para: encoder.layers.0.residual_connections.0
# Ativado save_debug para: encoder.layers.0.residual_connections.0.norm
# Ativado save_debug para: encoder.layers.0.residual_connections.1
# Ativado save_debug para: encoder.layers.0.residual_connections.1.norm
# Ativado save_debug para: encoder.norm
# Ativado save_debug para: decoder.layers.0.self_attention_block
# Ativado save_debug para: decoder.layers.0.cross_attention_block
# Ativado save_debug para: decoder.layers.0.feed_forward_block
# Ativado save_debug para: decoder.layers.0.residual_connections.0
# Ativado save_debug para: decoder.layers.0.residual_connections.0.norm
# Ativado save_debug para: decoder.layers.0.residual_connections.1
# Ativado save_debug para: decoder.layers.0.residual_connections.1.norm
# Ativado save_debug para: decoder.layers.0.residual_connections.2
# Ativado save_debug para: decoder.layers.0.residual_connections.2.norm
# Ativado save_debug para: decoder.norm
# Ativado save_debug para: src_embed
# Ativado save_debug para: tgt_embed
# Ativado save_debug para: src_pos
# Ativado save_debug para: tgt_pos
# Ativado save_debug para: projection_layer
# Debug info saved to slides/vars/InputEmbedding_0.json
# Debug info saved to slides/vars/PositionalEncoding_0.json
# Debug info saved to slides/vars/LayerNormalization_0.json
# Debug info saved to slides/vars/MultiHeadAttentionBlock_0.json
# Debug info saved to slides/vars/ResidualConnection_0.json
# Debug info saved to slides/vars/LayerNormalization_1.json
# Debug info saved to slides/vars/FeedForwardBlock_0.json
# Debug info saved to slides/vars/ResidualConnection_1.json
# Debug info saved to slides/vars/LayerNormalization_2.json
# Debug info saved to slides/vars/InputEmbedding_1.json
# Debug info saved to slides/vars/PositionalEncoding_1.json
# Debug info saved to slides/vars/LayerNormalization_3.json
# Debug info saved to slides/vars/MultiHeadAttentionBlock_1.json
# Debug info saved to slides/vars/ResidualConnection_2.json
# Debug info saved to slides/vars/LayerNormalization_4.json
# Debug info saved to slides/vars/MultiHeadAttentionBlock_2.json
# Debug info saved to slides/vars/ResidualConnection_3.json
# Debug info saved to slides/vars/LayerNormalization_5.json
# Debug info saved to slides/vars/FeedForwardBlock_1.json
# Debug info saved to slides/vars/ResidualConnection_4.json
# Debug info saved to slides/vars/LayerNormalization_6.json
# Debug info saved to slides/vars/ProjectionLayer_0.json
# Processing Epoch 99: 100%|████████████| 1/1 [00:00<00:00,  2.55it/s, loss=7.682]
# --------------------------------------------------------------------------------
#     SOURCE: CHORUS
#     TARGET: REFRÃO
#  PREDICTED: acredito frente
